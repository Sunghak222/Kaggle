# %%
import pandas as pd

# %%
test = pd.read_csv('test.csv')

# %%
submission = pd.DataFrame({
    'PassengerId': test['PassengerId'],
    'Survived': 0
})

# %%
submission.to_csv('submission/submission_all_not_survived.csv', index=False)
